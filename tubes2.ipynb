# %%
import numpy as np
import pandas as pd
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Dense
from backpropagation import FeedForwardNN

# %%
class MultiColumnLabelEncoder:
    '''
    Kelas ini berguna untuk melakukan label encoding pada setiap kolom dari
    data tabel 2 dimensi. Labelencoding akan mengubah data bernilai string
    menjadi angka secara acak (0,1,2, dst...)
    '''
    def __init__(self,columns = None):
        self.columns = columns # array berisi nama kolom yang ingin diencode
        self.le = preprocessing.LabelEncoder()

    def fit_transform(self,X):
        '''
        Mengencode dataframe X sesuai dengan kolom yang telah ditetapkan.
        '''
        output = X.copy()
        for col in self.columns:
            output[col] = self.le.fit_transform(output[col])
        return output

# %%
td = pd.read_csv("tennis.csv")
print ("===== Dataset =====\n")
print(td)
# Out:
# ===== Dataset =====
#
#      outlook temperature humidity   wind playtennis
# 0      sunny         hot     high  False         no
# 1      sunny         hot     high   True         no
# 2   overcast         hot     high  False        yes
# 3       rain        mild     high  False        yes
# 4       rain        cool   normal  False        yes
# 5       rain        cool   normal   True         no
# 6   overcast        cool   normal   True        yes
# 7      sunny        mild     high  False         no
# 8      sunny        cool   normal  False        yes
# 9       rain        mild   normal  False        yes
# 10     sunny        mild   normal   True        yes
# 11  overcast        mild     high   True        yes
# 12  overcast         hot   normal  False        yes
# 13      rain        mild     high   True         no

# %%
# encode dataset tenis dengan label encoder
td = MultiColumnLabelEncoder(columns = ['outlook','temperature','humidity','wind', 'playtennis']).fit_transform(td)
# split dataset secara acak jadi data training dan data tes dengan holdout split 10%
td_train, td_test = train_test_split(td, test_size=0.1)
td_train_labels = train['playtennis'].values
td_train_data = train.drop(columns=['playtennis']).values
td_test_labels = test['playtennis'].values
td_test_data = test.drop(columns=['playtennis']).values

# %%
# Implementasi keras dengan menggunakan model sequential dan layer dense
model = Sequential()
model.add(Dense(12, input_dim=4, activation='sigmoid'))
model.add(Dense(8, activation='sigmoid'))
model.add(Dense(1, activation='sigmoid'))
# Compile model
# loss menggunakan binary_crossentropy karena loss function ini cocok diterapkan 
#   pada dataset dengan label biner, 0 dan 1.
# Optimizer menggunakan stochastic gradient descent SGD
model.compile(loss='binary_crossentropy', optimizer='SGD', metrics=['accuracy'])
# Fit model dengan jumlah epoch 150 dan batch size 1 atau stochastic
model.fit(td_train_data, td_train_labels, epochs=150, batch_size=1)
# Evaluasi model terhadap data test
scores = model.evaluate(td_test_data, td_test_labels)
print("\n%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
# Out:
# Epoch 1/150
# 12/12 [==============================] - 1s 113ms/step - loss: 0.6468 - acc: 0.6667
# Epoch 2/150
# 12/12 [==============================] - 0s 4ms/step - loss: 0.6452 - acc: 0.6667
# Epoch 3/150
# 12/12 [==============================] - 0s 4ms/step - loss: 0.6438 - acc: 0.6667
# Epoch 4/150
# 12/12 [==============================] - 0s 4ms/step - loss: 0.6427 - acc: 0.6667
# Epoch 5/150
# 12/12 [==============================] - 0s 4ms/step - loss: 0.6418 - acc: 0.6667
# Epoch 6/150
# 12/12 [==============================] - 0s 7ms/step - loss: 0.6410 - acc: 0.6667
# Epoch 7/150
# 12/12 [==============================] - 0s 7ms/step - loss: 0.6402 - acc: 0.6667
# Epoch 8/150
# 12/12 [==============================] - 0s 5ms/step - loss: 0.6396 - acc: 0.6667
# Epoch 9/150
# 12/12 [==============================] - 0s 3ms/step - loss: 0.6391 - acc: 0.6667
# Epoch 10/150
# 12/12 [==============================] - 0s 3ms/step - loss: 0.6386 - acc: 0.6667
# Epoch 11/150
# 12/12 [==============================] - 0s 4ms/step - loss: 0.6381 - acc: 0.6667
# Epoch 12/150
# 12/12 [==============================] - 0s 7ms/step - loss: 0.6378 - acc: 0.6667
# Epoch 13/150
# 12/12 [==============================] - 0s 4ms/step - loss: 0.6374 - acc: 0.6667
# Epoch 14/150
# 12/12 [==============================] - 0s 3ms/step - loss: 0.6371 - acc: 0.6667
# Epoch 15/150
# 12/12 [==============================] - 0s 4ms/step - loss: 0.6368 - acc: 0.6667
# Epoch 16/150
# 12/12 [==============================] - 0s 4ms/step - loss: 0.6366 - acc: 0.6667
# Epoch 17/150
# 12/12 [==============================] - 0s 7ms/step - loss: 0.6363 - acc: 0.6667
# Epoch 18/150
# 12/12 [==============================] - 0s 3ms/step - loss: 0.6362 - acc: 0.6667
# Epoch 19/150
# 12/12 [==============================] - 0s 3ms/step - loss: 0.6360 - acc: 0.6667
# Epoch 20/150
# 12/12 [==============================] - 0s 3ms/step - loss: 0.6358 - acc: 0.6667
# Epoch 21/150
# 12/12 [==============================] - 0s 4ms/step - loss: 0.6356 - acc: 0.6667
# Epoch 22/150
# 12/12 [==============================] - 0s 3ms/step - loss: 0.6355 - acc: 0.6667
# Epoch 23/150
# 12/12 [==============================] - 0s 3ms/step - loss: 0.6353 - acc: 0.6667
# Epoch 24/150
# 12/12 [==============================] - 0s 3ms/step - loss: 0.6352 - acc: 0.6667
# Epoch 25/150
# 12/12 [==============================] - 0s 3ms/step - loss: 0.
150
# 12/12 [==============================] - 0s 3ms/step - loss: 0.6276 - acc: 0.6667
# Epoch 96/150
# 12/12 [==============================] - 0s 3ms/step - loss: 0.6274 - acc: 0.6667
# Epoch 97/150
# 12/12 [==============================] - 0s 3ms/step - loss: 0.6274 - acc: 0.6667
# Epoch 98/150
# 12/12 [==============================] - 0s 3ms/step - loss: 0.6272 - acc: 0.6667
# Epoch 99/150
# 12/12 [==============================] - ETA: 0s - loss: 0.4176 - acc: 1.000 - 0s 3ms/step - loss: 0.6271 - acc: 0.6667
# Epoch 100/150
# 12/12 [==============================] - 0s 3ms/step - loss: 0.6270 - acc: 0.6667
# Epoch 101/150
# 12/12 [==============================] - 0s 3ms/step - loss: 0.6269 - acc: 0.6667
# Epoch 102/150
# 12/12 [==============================] - 0s 3ms/step - loss: 0.6267 - acc: 0.6667
# Epoch 103/150
# 12/12 [==============================] - 0s 3ms/step - loss: 0.6267 - acc: 0.6667
# Epoch 104/150
# 12/12 [==============================] - 0s 3ms/step - loss: 0.6265 - acc: 0.6667
# Epoch 105/150
# 12/12 [==============================] - 0s 3ms/step - loss: 0.6264 - acc: 0.6667
# Epoch 106/150
# 12/12 [==============================] - 0s 2ms/step - loss: 0.6263 - acc: 0.6667
# Epoch 107/150
# 12/12 [==============================] - 0s 3ms/step - loss: 0.6261 - acc: 0.6667
# Epoch 108/150
# 12/12 [==============================] - 0s 7ms/step - loss: 0.6261 - acc: 0.6667
# Epoch 109/150
# 12/12 [==============================] - 0s 5ms/step - loss: 0.6259 - acc: 0.6667
# Epoch 110/150
# 12/12 [==============================] - 0s 4ms/step - loss: 0.6258 - acc: 0.6667
# Epoch 111/150
# 12/12 [==============================] - 0s 6ms/step - loss: 0.6257 - acc: 0.6667
# Epoch 112/150
# 12/12 [==============================] - 0s 3ms/step - loss: 0.6255 - acc: 0.6667
# Epoch 113/150
# 12/12 [==============================] - 0s 3ms/step - loss: 0.6254 - acc: 0.6667
# Epoch 114/150
# 12/12 [==============================] - 0s 3ms/step - loss: 0.6253 - acc: 0.6667
# Epoch 115/150
# 12/12 [==============================] - 0s 4ms/step - loss: 0.6252 - acc: 0.6667
# Epoch 116/150
# 12/12 [==============================] - 0s 4ms/step - loss: 0.6251 - acc: 0.6667
# Epoch 117/150
# 12/12 [==============================] - 0s 4ms/step - loss: 0.6250 - acc: 0.6667
# Epoch 118/150
# 12/12 [==============================] - 0s 3ms/step - loss: 0.6248 - acc: 0.6667
# Epoch 119/150
# 12/12 [==============================] - 0s 3ms/step - loss: 0.6247 - acc: 0.6667
# Epoch 120/150
# 12/12 [==============================] - 0s 4ms/step - loss: 0.6246 - acc: 0.6667
# Epoch 121/150
# 12/12 [==============================] - 0s 2ms/step - loss: 0.6245 - acc: 0.6667
# Epoch 122/150
# 12/12 [==============================] - 0s 4ms/step - loss: 0.6243 - acc: 0.6667
# Epoch 123/150
# 12/12 [==============================] - 0s 3ms/step - loss: 0.6243 - acc: 0.6667
# Epoch 124/150
# 12/12 [==============================] - 0s 3ms/step - loss: 0.6241 - acc: 0.6667
# Epoch 125/150
# 12/12 [==============================] - 0s 3ms/step - loss: 0.6240 - acc: 0.6667
# Epoch 126/150
# 12/12 [==============================] - 0s 3ms/step - loss: 0.6238 - acc: 0.6667
# Epoch 127/150
# 12/12 [==============================] - 0s 4ms/step - loss: 0.6237 - acc: 0.6667
# Epoch 128/150
# 12/12 [==============================] - 0s 4ms/step - loss: 0.6236 - acc: 0.6667
# Epoch 129/150
# 12/12 [==============================] - 0s 3ms/step - loss: 0.6235 - acc: 0.6667
# Epoch 130/150
# 12/12 [==============================] - 0s 3ms/step - loss: 0.6233 - acc: 0.6667
# Epoch 131/150
# 12/12 [==============================] - 0s 3ms/step - loss: 0.6231 - acc: 0.6667
# Epoch 132/150
# 12/12 [==============================] - 0s 3ms/step - loss: 0.6230 - acc: 0.6667
# Epoch 133/150
# 12/12 [==============================] - 0s 3ms/step - loss: 0.6230 - acc: 0.6667
# Epoch 134/150
# 12/12 [==============================] - 0s 3ms/step - loss: 0.6228 - acc: 0.6667
# Epoch 135/150
# 12/12 [==============================] - 0s 4ms/step - loss: 0.6227 - acc: 0.6667
# Epoch 136/150
# 12/12 [==============================] - 0s 3ms/step - loss: 0.6226 - acc: 0.6667
# Epoch 137/150
# 12/12 [==============================] - 0s 3ms/step - loss: 0.6224 - acc: 0.6667
# Epoch 138/150
# 12/12 [==============================] - 0s 3ms/step - loss: 0.6223 - acc: 0.6667
# Epoch 139/150
# 12/12 [==============================] - 0s 3ms/step - loss: 0.6222 - acc: 0.6667
# Epoch 140/150
# 12/12 [==============================] - 0s 3ms/step - loss: 0.6221 - acc: 0.6667
# Epoch 141/150
# 12/12 [==============================] - 0s 3ms/step - loss: 0.6219 - acc: 0.6667
# Epoch 142/150
# 12/12 [==============================] - 0s 6ms/step - loss: 0.6218 - acc: 0.6667
# Epoch 143/150
# 12/12 [==============================] - 0s 2ms/step - loss: 0.6216 - acc: 0.6667
# Epoch 144/150
# 12/12 [==============================] - 0s 3ms/step - loss: 0.6215 - acc: 0.6667
# Epoch 145/150
# 12/12 [==============================] - 0s 3ms/step - loss: 0.6213 - acc: 0.6667
# Epoch 146/150
# 12/12 [==============================] - 0s 2ms/step - loss: 0.6212 - acc: 0.6667
# Epoch 147/150
# 12/12 [==============================] - 0s 2ms/step - loss: 0.6210 - acc: 0.6667
# Epoch 148/150
# 12/12 [==============================] - 0s 3ms/step - loss: 0.6209 - acc: 0.6667
# Epoch 149/150
# 12/12 [==============================] - 0s 3ms/step - loss: 0.6208 - acc: 0.6667
# Epoch 150/150
# 12/12 [==============================] - 0s 2ms/step - loss: 0.6207 - acc: 0.6667
# 2/2 [==============================] - 0s 194ms/step
#
# acc: 50.00%

# %%
# Implementasi feed forward NN dengan backpropagation
# hiddenlayer 2 dengan jumlah neuron 12 dan 8
# batch size 1 atau stochastic karena data sedikit.
ffnn = FeedForwardNN((12, 8), batch_size=1, max_iter=10000, momentum=0.5, learning_rate=0.01)
ffnn.fit(td_train_data, td_train_labels)

# hitung akurasi dengan membandingkan hasil prediksi dan label sesungguhnya.
acc = 0
correct = 0
n = 0
for a, b in zip(ffnn.predict(td_test_data, discrete=True), td_test_labels):
    print(a, b)
    if (a==b):
        correct+=1
    n+=1
print("acc:", correct/n * 100, "%")
# Out:
# 1.0 1
# 1.0 0
# acc: 50.0 %
